# %% [markdown]
# ### Getting a list of airline companies
#
# Sourced from OpenFligts, below follow some data simplification for the purposes of this project.

# %%
import pandas as pd

# %%
df = pd.read_csv('data/airlines.dat')

# %%
df
# Out:
#          -1                                       Unknown  \
# 0         1                                Private flight
# 1         2                                   135 Airways
# 2         3                                 1Time Airline
# 3         4  2 Sqn No 1 Elementary Flying Training School
# 4         5                               213 Flight Unit
# 5         6                 223 Flight Unit State Airline
# 6         7                             224th Flight Unit
# 7         8                                   247 Jet Ltd
# 8         9                                   3D Aviation
# 9        10                                   40-Mile Air
# 10       11                                        4D Air
# 11       12                        611897 Alberta Limited
# 12       13                              Ansett Australia
# 13       14                          Abacus International
# 14       15                               Abelag Aviation
# ...
